# %%
import json
import facebook
import requests
import pandas as pd
import sqlite3
#from config import SQL_SCHEMA

SQL_SCHEMA = ['id', 'title', 'description', 'date_published', 'views', 'likes', 'comments', 'medium']
ACCESS_TOKEN = 'EAAJ4UPd2WskBAFhsqwJLJ2WrBg2XWyyTUXAnlJu2p4osXl2GLjGD3pjhDZClStaQ7cIU9ZBfbMyUJZA8qbblrncaa5ntzOEZCdMprfqZBBNaZCxqZAnJA26eZB04etY7GYfoTR3hl8NhNoIeHQscEuf6HereDQfDtrYwiFYdDznUhQZDZD'
page_id = '119750011511269'
video_id = ''
video_list = []
video_insights_list = []
token = ACCESS_TOKEN
graph = facebook.GraphAPI(token)
print('here')
videos = graph.get_all_connections(id=page_id, connection_name='videos', fields='id, title, description, created_time')
for video in videos:
    try:
        video_list.append(video)
    except:
        continue
print(video_list)
# Out:
# here

# %%
for video in video_list:
        video_insights = graph.get_connections(id=video['id'],
                                               connection_name='video_insights',
                                               metric='total_video_views, total_video_stories_by_action_type',
                                               fields='values, id')
        video_insights_list.append(video_insights)

# %%
for c in range(len(video_list)):
    try:
        facebook_df['id'][c] = video_list[c]['id']
    except:
        continue
    try:
        facebook_df['title'][c] = video_list[c]['title']
    except:
        continue
    try:
        facebook_df['description'][c] = video_list[c]['description']
    except:
        continue
    try:
        facebook_df['date_published'][c] = video_list[c]['created_time']
    except:
        continue
# Out:
# 0      352728366115496
# 1     1234138873601756
# 2      683163315876752
# 3      875196306340063
# 4     3300673073313007
#             ...
# 66     299635913522677
# 67     299634600189475
# 68     299001273586141
# 69     298100457009556
# 70     297365417083060
# Name: id, Length: 71, dtype: object

# %%
facebook_video_list = []
for video in zip(video_list, video_insights_list):
    facebook_video_list.append(video)
facebook_video_list[0]
# Out:
# ({'id': '352728366115496', 'created_time': '2020-08-21T13:59:47+0000'},
#  {'data': [{'values': [{'value': 90}],
#     'id': '352728366115496/video_insights/total_video_views/lifetime'},
#    {'values': [{'value': {'share': 4, 'like': 11, 'comment': 4}}],
#     'id': '352728366115496/video_insights/total_video_stories_by_action_type/lifetime'}]})

# %%
facebook_df = pd.DataFrame(index=range(len(video_list)), columns=SQL_SCHEMA)
for c in range(len(facebook_video_list)):
    facebook_df['id'][c] = facebook_video_list[c][0]['id']
    try:
        facebook_df['title'][c] = facebook_video_list[c][0]['title']
    except:
        pass
    try:
        facebook_df['description'][c] = facebook_video_list[c][0]['description']
    except:
        pass
    facebook_df['date_published'][c] = facebook_video_list[c][0]['created_time']
    try:
        facebook_df['views'][c] = facebook_video_list[c][1]['data'][0]['values'][0]['value']
    except:
        pass
    try:
        facebook_df['likes'][c] = facebook_video_list[c][1]['data'][1]['values'][0]['value']['like']
    except:
        pass
    try:
        facebook_df['comments'][c] = facebook_video_list[c][1]['data'][1]['values'][0]['value']['comment']
    except:
        pass
    facebook_df['medium'][c] = 'facebook'
facebook_df.head(50)
# Out:
#                   id                                       title  \
# 0    352728366115496                                         NaN
# 1   1234138873601756              ReThink: What is Eternal Life?
# 2    683163315876752                                         NaN
# 3    875196306340063            ReThink: Who is the Holy Spirit?
# 4   3300673073313007               ReThingk: What is the Church?
# 5    981518438942902                                         NaN
# 6    671758730088154                                         NaN
# 7    727425118036996  Friday Morning worship with the Moderwells
# 8    706194283561399                                         NaN
# 9    637915950149800                                         NaN
# 10  3204932256232196                                         NaN
# 11   202320561018612                                         NaN
# 12   678702089384207                                         NaN
# 13   205900157161779                                         NaN
# 14   703911433718602                                         NaN
# 15   267919257901866                                         NaN
# 16   686566985254786                                         NaN
# 17   943759979377679                                         NaN
# 18  3080505118697419                                         NaN
# 19   273774700482828                                         NaN
# 20   268218684379972                                         NaN
# 21  3188845747826556                                         NaN
# 22  2493855157610884                        Friday Worship - Raz
# 23   675805376299141                                         NaN
# 24  1399299773592445                                         NaN
# 25   681069542724418                                         NaN
# 26  1123924654636756                                         NaN
# 27   300053644324110                                         NaN
# 28  1662267633897358                                         NaN
# 29   551768325325029                                         NaN
# 30   252067662823054                                         NaN
# 31   282673039391617                                         NaN
# 32  2864257007028149                                         NaN
# 33   222608848829982                                         NaN
# 34  3010009472417076                                         NaN
# 35  1062186500834937                                         NaN
# 36   537364903862179                                         NaN
# 37  3051491248249564                                         NaN
# 38   928413264261574                                         NaN
# 39  2854675921315158                                         NaN
# 40   278330019829717                                         NaN
# 41   892109337876357                                         NaN
# 42   206759037406904                                         NaN
# 43   532100557743032                                         NaN
# 44  1321621131368083                                         NaN
# 45   206416820683385                                         NaN
# 46   199005968207991                                         NaN
# 47   526408258276167                                         NaN
# 48   858830080936588                                         NaN
# 49   845602742259322                                         NaN
#
#                                           description  \
# 0                                                 NaN
# 1          4 Common Misconceptions about Eternal Life
# 2                                                 NaN
# 3   The sermon will be focused on the relational a...
# 4                                                 NaN
# 5                                                 NaN
# 6   Worship Night in the parking lot behind the ch...
# 7   We miss being with all of you and hope you can...
# 8                                                 NaN
# 9                                                 NaN
# 10                        Hey Welcome in to Worship!!
# 11                                                NaN
# 12                         Ed Wilson Memorial Service
# 13                                                NaN
# 14                                                NaN
# 15                          Pentecost Worship Service
# 16  Hey Y’all I went up to check out our spot for ...
# 17                                                NaN
# 18                       Welcome to Wednesday Worship
# 19                 Welcome to Wednesday Worship Y’all
# 20                                                NaN
# 21                                                NaN
# 22  Come with me to the throne where we will worsh...
# 23                                                NaN
# 24            Wednesday Afternoon Live Worship 5/6/20
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  Hey All, Thanks for joining me in worship this...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48  Hey everyone, as part of our journey of racial...
# 49  A few years ago we felt led to move our VBS to...
#
#               date_published views likes comments    medium
# 0   2020-08-21T13:59:47+0000    90    11        4  facebook
# 1   2020-08-16T12:45:22+0000   142    21       16  facebook
# 2   2020-08-14T13:53:42+0000    49     3        2  facebook
# 3   2020-08-09T12:45:15+0000   267    12        7  facebook
# 4   2020-08-02T12:47:46+0000    71     4      NaN  facebook
# 5   2020-07-31T13:51:06+0000    41     6        1  facebook
